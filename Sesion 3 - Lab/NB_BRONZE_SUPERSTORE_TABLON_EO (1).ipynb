# %% [markdown]
# # Dataset SuperStore
#
# * URL = https://www.kaggle.com/code/aaaaammmmmm99/superstore/notebook

# %% [markdown]
# # Cargar Librerias

# %%
import pandas as pd
# Out:
# StatementMeta(, 8ec5b7fc-985c-4237-99b4-286e7a2a24be, 8, Finished, Available, Finished, False)

# %% [markdown]
# # Cargar Tablon de datos en zona broze

# %%
path_file = "/lakehouse/default/Files/EDUARDO OSORIO/XLSX/SuperStore_Tablon.xlsx"
df = pd.read_excel(path_file)
# Out:
# StatementMeta(, 8ec5b7fc-985c-4237-99b4-286e7a2a24be, 9, Finished, Available, Finished, False)

# %% [markdown]
# # Mostrar registros

# %%
df.head()
# Out:
# StatementMeta(, 8ec5b7fc-985c-4237-99b4-286e7a2a24be, 10, Finished, Available, Finished, False)
#    Row_ID        Order_ID Order_Date  Ship_Date       Ship_Mode Customer_ID  \
# 0       1  CA-2017-152156 2017-11-08 2017-11-11    Second Class    CG-12520
# 1       2  CA-2017-152156 2017-11-08 2017-11-11    Second Class    CG-12520
# 2       3  CA-2017-138688 2017-06-12 2017-06-16    Second Class    DV-13045
# 3       4  US-2016-108966 2016-10-11 2016-10-18  Standard Class    SO-20335
# 4       5  US-2016-108966 2016-10-11 2016-10-18  Standard Class    SO-20335
#
#      Customer_Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3    Sean O Donnel   Consumer  United States  Fort Lauderdale     Florida
# ...

# %% [markdown]
# # Conocer estructura de datos de mi DF

# %%
df.info()
# Out:
# StatementMeta(, 4ad6c43d-8e69-4ed1-885a-02de8a0cb8ec, 8, Finished, Available, Finished, False)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9800 entries, 0 to 9799
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row_ID         9800 non-null   int64
#  1   Order_ID       9800 non-null   object
#  2   Order_Date     9800 non-null   datetime64[ns]
#  3   Ship_Date      9800 non-null   datetime64[ns]
#  4   Ship_Mode      9800 non-null   object
#  5   Customer_ID    9800 non-null   object
#  6   Customer_Name  9800 non-null   object
#  7   Segment        9800 non-null   object
#  8   Country        9800 non-null   object
#  9   City           9800 non-null   object
#  10  State          9800 non-null   object
#  11  Postal_Code    9789 non-null   float64
#  12  Region         9800 non-null   object
#  13  Product_ID     9800 non-null   object
#  14  Category       9800 non-null   object
# ...

# %% [markdown]
# # Crear df_spark para escribir en mi lakehouse

# %%
df_spark = spark.createDataFrame(df)
display(df_spark.limit(10))
# Out:
# StatementMeta(, 4ad6c43d-8e69-4ed1-885a-02de8a0cb8ec, 9, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 047592f8-9de3-4855-8e33-d26d7181f124)

# %% [markdown]
# # Escribir df como tabla

# %%
# ruta local del Lakehouse dentro del notebook
NAME_LH = "LH_BRONZE_ESSENTIALS"
NAME_SCHEMA = "dbo"
NAME_TB = "superstore_tablon_eo"
TABLA_BRONZE = f"{NAME_LH}.{NAME_SCHEMA}.{NAME_TB}"
# Out:
# StatementMeta(, 4ad6c43d-8e69-4ed1-885a-02de8a0cb8ec, 14, Finished, Available, Finished, False)

# %%
df_spark.write.format("delta").mode("overwrite").option("overwriteSchema", "true").saveAsTable(TABLA_BRONZE)
# Out:
# StatementMeta(, 4ad6c43d-8e69-4ed1-885a-02de8a0cb8ec, 15, Finished, Available, Finished, False)
